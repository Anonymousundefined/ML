# %% [markdown]
# <a href="https://colab.research.google.com/github/Anonymousundefined/ML/blob/main/Panda_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
shelf1={
    "name":['anmol','manas','anonymous'],
    "marks":[100,11,33],
    "city":["kanpur","mp","lko"]
}

# %%
df=pd.DataFrame(shelf1)
df
# Out:
#         name  marks    city
# 0      anmol    100  kanpur
# 1      manas     11      mp
# 2  anonymous     33     lko

# %%
df.to_csv('list.csv')

# %%
df.to_csv('a.csv',index=False)

# %%
df.head(2)
# Out:
#     name  marks    city
# 0  anmol    100  kanpur
# 1  manas     11      mp

# %%
df.tail(1)
# Out:
#         name  marks city
# 2  anonymous     33  lko

# %%
df
# Out:
#         name  marks    city
# 0      anmol    100  kanpur
# 1      manas     11      mp
# 2  anonymous     33     lko

# %%
anmol=pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
anmol
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
anmol.head(20)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 1     -114.47     34.40                19.0       7650.0          1901.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 3     -114.57     33.64                14.0       1501.0           337.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 5     -114.58     33.63                29.0       1387.0           236.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 7     -114.59     34.83                41.0        812.0           168.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 9     -114.60     34.83                46.0       1497.0           309.0
# 10    -114.60     33.62                16.0       3741.0           801.0
# 11    -114.60     33.60                21.0       1988.0           483.0
# ...

# %%
anmol2=pd.read_csv('list.csv')

# %%
anmol2
# Out:
#    Unnamed: 0       name  marks    city
# 0           0      anmol    100  kanpur
# 1           1      manas     11      mp
# 2           2  anonymous     33     lko

# %%
anmol2['marks']
# Out:
# 0    100
# 1     11
# 2     33
# Name: marks, dtype: int64

# %%
anmol2['city']
# Out:
# first     kanpur
# second        mp
# third        lko
# Name: city, dtype: object

# %%
anmol2['marks'][1]=50
# Out:
# <ipython-input-16-cd48a7b48f63>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anmol2['marks'][1]=50

# %%
anmol2
# Out:
#    Unnamed: 0       name  marks    city
# 0           0      anmol    100  kanpur
# 1           1      manas     50      mp
# 2           2  anonymous     33     lko

# %%
anmol2.to_csv('anmol3.csv')

# %%
anmol2.index=['first','second','third']

# %%
anmol2
# Out:
#         Unnamed: 0       name  marks    city
# first            0      anmol    100  kanpur
# second           1      manas     50      mp
# third            2  anonymous     33     lko

# %% [markdown]
# seies is 1d,combination of series lead to dataset[link text](https://)

# %%
ab=pd.Series(np.random.rand(43))

# %%
ab
# Out:
# 0     0.977986
# 1     0.556558
# 2     0.213656
# 3     0.658098
# 4     0.019924
# 5     0.771452
# 6     0.466901
# 7     0.806059
# 8     0.930389
# 9     0.598231
# 10    0.418814
# 11    0.184551
# 12    0.945372
# 13    0.170073
# 14    0.791360
# 15    0.258173
# 16    0.751595
# 17    0.694540
# 18    0.101503
# 19    0.702531
# 20    0.905027
# 21    0.667844
# 22    0.323483
# 23    0.993981
# 24    0.180674
# 25    0.780821
# 26    0.365832
# 27    0.745112
# 28    0.694904
# 29    0.007874
# 30    0.979927
# 31    0.766746
# 32    0.303622
# 33    0.614744
# 34    0.795937
# 35    0.020913
# 36    0.617597
# 37    0.114031
# 38    0.507466
# 39    0.676953
# 40    0.421053
# 41    0.951337
# 42    0.287072
# dtype: float64

# %%
ndf=pd.DataFrame(np.random.rand(300,4))

# %%
ndf
# Out:
#             0         1         2         3
# 0    0.233571  0.940627  0.840973  0.339155
# 1    0.480224  0.920644  0.908747  0.840264
# 2    0.863396  0.460673  0.686579  0.920673
# 3    0.169892  0.594916  0.958665  0.170329
# 4    0.594134  0.429016  0.462970  0.399774
# ..        ...       ...       ...       ...
# 295  0.593415  0.047831  0.193854  0.773899
# 296  0.652876  0.064104  0.276512  0.482867
# 297  0.073715  0.675179  0.299568  0.362048
# 298  0.608244  0.823857  0.948687  0.724952
# 299  0.174493  0.511020  0.508406  0.306057
#
# [300 rows x 4 columns]

# %%
type(ndf)
# Out:
# pandas.core.frame.DataFrame

# %%
type(ab)
# Out:
# pandas.core.series.Series

# %%
ndf.describe()
# Out:
#                 0           1           2           3
# count  300.000000  300.000000  300.000000  300.000000
# mean     0.480696    0.480679    0.511518    0.517876
# std      0.295347    0.286034    0.284503    0.287005
# min      0.000182    0.004914    0.004460    0.006734
# 25%      0.222991    0.236266    0.256927    0.284176
# 50%      0.470454    0.453076    0.508777    0.548161
# 75%      0.753283    0.701113    0.762863    0.761949
# max      0.995169    0.986595    0.999401    0.997874

# %%
ndf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
ndf[0][0]="anmol"

# %%
ndf
# Out:
#             0         1         2         3
# 0       anmol  0.940627  0.840973  0.339155
# 1    0.480224  0.920644  0.908747  0.840264
# 2    0.863396  0.460673  0.686579  0.920673
# 3    0.169892  0.594916  0.958665  0.170329
# 4    0.594134  0.429016  0.462970  0.399774
# ..        ...       ...       ...       ...
# 295  0.593415  0.047831  0.193854  0.773899
# 296  0.652876  0.064104  0.276512  0.482867
# 297  0.073715  0.675179  0.299568  0.362048
# 298  0.608244  0.823857  0.948687  0.724952
# 299  0.174493  0.511020  0.508406  0.306057
#
# [300 rows x 4 columns]

# %%
ndf.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
ndf.index
# Out:
# RangeIndex(start=0, stop=300, step=1)

# %%
ndf.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
ndf[0][0]=0
# Out:
# <ipython-input-45-05a9a1ddb85b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf[0][0]=0

# %%
ndf.to_numpy()
# Out:
# array([[0, 0.9406269526225207, 0.8409729416650439, 0.33915548811864626],
#        [0.4802239486018348, 0.9206438928280755, 0.9087467721022467,
#         0.8402639149366052],
#        [0.8633960144960905, 0.46067276678268165, 0.6865794988824178,
#         0.9206732192588585],
#        ...,
#        [0.0737150299213073, 0.6751791583438842, 0.2995681375597209,
#         0.3620482573160816],
#        [0.6082443825602231, 0.8238567766668029, 0.9486873440911908,
#         0.7249516263393827],
#        [0.17449310236816518, 0.5110199758499159, 0.5084064852533703,
#         0.306057023627314]], dtype=object)

# %%
ndf.T
# Out:
#         0         1         2         3         4         5         6    \
# 0         0  0.480224  0.863396  0.169892  0.594134  0.260703  0.776872
# 1  0.940627  0.920644  0.460673  0.594916  0.429016  0.796855  0.288987
# 2  0.840973  0.908747  0.686579  0.958665   0.46297  0.599583  0.992269
# 3  0.339155  0.840264  0.920673  0.170329  0.399774  0.611426  0.841202
#
#         7         8         9    ...       290       291       292       293  \
# 0  0.234726  0.465776  0.646736  ...  0.796406  0.510611  0.064524  0.786731
# 1  0.070635  0.640719  0.086706  ...  0.404451  0.534732  0.004914  0.832421
# 2  0.724676  0.194994  0.478662  ...  0.390537  0.944243  0.842176  0.386327
# 3  0.667663  0.467065  0.194198  ...  0.899537  0.988857  0.827832  0.433576
#
#         294       295       296       297       298       299
# 0  0.650526  0.593415  0.652876  0.073715  0.608244  0.174493
# 1  0.203597  0.047831  0.064104  0.675179  0.823857   0.51102
# ...

# %%
ndf
# Out:
#             0         1         2         3
# 0           0  0.940627  0.840973  0.339155
# 1    0.480224  0.920644  0.908747  0.840264
# 2    0.863396  0.460673  0.686579  0.920673
# 3    0.169892  0.594916  0.958665  0.170329
# 4    0.594134  0.429016  0.462970  0.399774
# ..        ...       ...       ...       ...
# 295  0.593415  0.047831  0.193854  0.773899
# 296  0.652876  0.064104  0.276512  0.482867
# 297  0.073715  0.675179  0.299568  0.362048
# 298  0.608244  0.823857  0.948687  0.724952
# 299  0.174493  0.511020  0.508406  0.306057
#
# [300 rows x 4 columns]

# %%
ndf.sort_index(axis=1,ascending=False)
# Out:
#             3         2         1         0
# 0    0.339155  0.840973  0.940627         0
# 1    0.840264  0.908747  0.920644  0.480224
# 2    0.920673  0.686579  0.460673  0.863396
# 3    0.170329  0.958665  0.594916  0.169892
# 4    0.399774  0.462970  0.429016  0.594134
# ..        ...       ...       ...       ...
# 295  0.773899  0.193854  0.047831  0.593415
# 296  0.482867  0.276512  0.064104  0.652876
# 297  0.362048  0.299568  0.675179  0.073715
# 298  0.724952  0.948687  0.823857  0.608244
# 299  0.306057  0.508406  0.511020  0.174493
#
# [300 rows x 4 columns]

# %%
 type(ndf[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# copy and view ==pointer
# ndf2=ndf link [view] [jusat a pointer] not a copy

# %%
ndf2=ndf[]

# %%
ndf[0][0]=0.99999
# Out:
# <ipython-input-56-a7e20487f6dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf[0][0]=0.99999

# %%
ndf2.head()
# Out:
#           0         1         2         3
# 0   0.99999  0.940627  0.840973  0.339155
# 1  0.480224  0.920644  0.908747  0.840264
# 2  0.863396  0.460673  0.686579  0.920673
# 3  0.169892  0.594916  0.958665  0.170329
# 4  0.594134  0.429016  0.462970  0.399774

# %%
ndf3=ndf.copy()

# %%
ndf[0][0]=0.87535
# Out:
#   File "<ipython-input-64-99821bfac6f4>", line 1
#     ndf[0][0]=0.87535//view or copy return doubt
#                                     ^
# SyntaxError: invalid syntax

# %%
ndf3
# Out:
#             0         1         2         3
# 0     0.99999  0.940627  0.840973  0.339155
# 1    0.480224  0.920644  0.908747  0.840264
# 2    0.863396  0.460673  0.686579  0.920673
# 3    0.169892  0.594916  0.958665  0.170329
# 4    0.594134  0.429016  0.462970  0.399774
# ..        ...       ...       ...       ...
# 295  0.593415  0.047831  0.193854  0.773899
# 296  0.652876  0.064104  0.276512  0.482867
# 297  0.073715  0.675179  0.299568  0.362048
# 298  0.608244  0.823857  0.948687  0.724952
# 299  0.174493  0.511020  0.508406  0.306057
#
# [300 rows x 4 columns]

# %% [markdown]
# ndf[0][0] error bcz it can return copy or view so we use loc ♒

# %%
ndf.columns=list("ABCD")
ndf
# Out:
#             A         B         C         D
# 0     0.87535  0.940627  0.840973  0.339155
# 1    0.480224  0.920644  0.908747  0.840264
# 2    0.863396  0.460673  0.686579  0.920673
# 3    0.169892  0.594916  0.958665  0.170329
# 4    0.594134  0.429016  0.462970  0.399774
# ..        ...       ...       ...       ...
# 295  0.593415  0.047831  0.193854  0.773899
# 296  0.652876  0.064104  0.276512  0.482867
# 297  0.073715  0.675179  0.299568  0.362048
# 298  0.608244  0.823857  0.948687  0.724952
# 299  0.174493  0.511020  0.508406  0.306057
#
# [300 rows x 4 columns]

# %%
ndf.loc[0,0]=654

# %%
ndf.loc[0,'A']=653

# %%
ndf
# Out:
#             A         B         C         D      0
# 0         653  0.940627  0.840973  0.339155  654.0
# 1    0.480224  0.920644  0.908747  0.840264    NaN
# 2    0.863396  0.460673  0.686579  0.920673    NaN
# 3    0.169892  0.594916  0.958665  0.170329    NaN
# 4    0.594134  0.429016  0.462970  0.399774    NaN
# ..        ...       ...       ...       ...    ...
# 295  0.593415  0.047831  0.193854  0.773899    NaN
# 296  0.652876  0.064104  0.276512  0.482867    NaN
# 297  0.073715  0.675179  0.299568  0.362048    NaN
# 298  0.608244  0.823857  0.948687  0.724952    NaN
# 299  0.174493  0.511020  0.508406  0.306057    NaN
#
# [300 rows x 5 columns]

# %%
ndf=ndf.drop(0,axis=1)

# %%
ndf.loc[:,['C','A']]
# Out:
#             C         A
# 0    0.840973       653
# 1    0.908747  0.480224
# 2    0.686579  0.863396
# 3    0.958665  0.169892
# 4    0.462970  0.594134
# ..        ...       ...
# 295  0.193854  0.593415
# 296  0.276512  0.652876
# 297  0.299568  0.073715
# 298  0.948687  0.608244
# 299  0.508406  0.174493
#
# [300 rows x 2 columns]

# %% [markdown]
# QUERY

# %%
ndf.loc[(ndf['A']<0.3) & (ndf['C']>0.5) & (ndf['D']>0.8)]
# Out:
#             A         B         C         D
# 59    0.00265  0.151170  0.674791  0.871189
# 188  0.112144  0.642891  0.941902  0.885415
# 199  0.159261  0.504177  0.722045  0.892935
# 215  0.006902  0.452935  0.982525  0.866799
# 224   0.05125  0.113834  0.791738  0.972335
# 239  0.269725  0.459997  0.725086  0.854768
# 244  0.273189  0.025510  0.639905  0.858531
# 245  0.061827  0.350377  0.537607  0.824451
# 271  0.149559  0.228757  0.931815  0.971785
# 292  0.064524  0.004914  0.842176  0.827832

# %% [markdown]
# loc for name and iloc for index

# %%
ndf.iloc[0,3]
# Out:
# 0.33915548811864626

# %%
ndf.iloc[[0,288],[1,2]]
# Out:
#             B         C
# 0    0.940627  0.840973
# 288  0.619595  0.192924

# %%
ndf
# Out:
#             A         B         C         D
# 0         653  0.940627  0.840973  0.339155
# 1    0.480224  0.920644  0.908747  0.840264
# 2    0.863396  0.460673  0.686579  0.920673
# 3    0.169892  0.594916  0.958665  0.170329
# 4    0.594134  0.429016  0.462970  0.399774
# ..        ...       ...       ...       ...
# 295  0.593415  0.047831  0.193854  0.773899
# 296  0.652876  0.064104  0.276512  0.482867
# 297  0.073715  0.675179  0.299568  0.362048
# 298  0.608244  0.823857  0.948687  0.724952
# 299  0.174493  0.511020  0.508406  0.306057
#
# [300 rows x 4 columns]

# %%
ndf.drop([0])
# Out:
#             A         B         C         D
# 1    0.480224  0.920644  0.908747  0.840264
# 2    0.863396  0.460673  0.686579  0.920673
# 3    0.169892  0.594916  0.958665  0.170329
# 4    0.594134  0.429016  0.462970  0.399774
# 5    0.260703  0.796855  0.599583  0.611426
# ..        ...       ...       ...       ...
# 295  0.593415  0.047831  0.193854  0.773899
# 296  0.652876  0.064104  0.276512  0.482867
# 297  0.073715  0.675179  0.299568  0.362048
# 298  0.608244  0.823857  0.948687  0.724952
# 299  0.174493  0.511020  0.508406  0.306057
#
# [299 rows x 4 columns]

# %%
ndf
# Out:
#             A         B         C         D
# 0         653  0.940627  0.840973  0.339155
# 1    0.480224  0.920644  0.908747  0.840264
# 2    0.863396  0.460673  0.686579  0.920673
# 3    0.169892  0.594916  0.958665  0.170329
# 4    0.594134  0.429016  0.462970  0.399774
# ..        ...       ...       ...       ...
# 295  0.593415  0.047831  0.193854  0.773899
# 296  0.652876  0.064104  0.276512  0.482867
# 297  0.073715  0.675179  0.299568  0.362048
# 298  0.608244  0.823857  0.948687  0.724952
# 299  0.174493  0.511020  0.508406  0.306057
#
# [300 rows x 4 columns]

# %%
ndf.drop(['A','B'],axis=1)
# Out:
#             C         D
# 0    0.840973  0.339155
# 1    0.908747  0.840264
# 2    0.686579  0.920673
# 3    0.958665  0.170329
# 4    0.462970  0.399774
# ..        ...       ...
# 295  0.193854  0.773899
# 296  0.276512  0.482867
# 297  0.299568  0.362048
# 298  0.948687  0.724952
# 299  0.508406  0.306057
#
# [300 rows x 2 columns]

# %%
ndf.drop(['A'],axis=1,inplace=True)

# %%
ndf
# Out:
#             B         C         D
# 1    0.920644  0.908747  0.840264
# 5    0.796855  0.599583  0.611426
# 7    0.070635  0.724676  0.667663
# 8    0.640719  0.194994  0.467065
# 9    0.086706  0.478662  0.194198
# ..        ...       ...       ...
# 295  0.047831  0.193854  0.773899
# 296  0.064104  0.276512  0.482867
# 297  0.675179  0.299568  0.362048
# 298  0.823857  0.948687  0.724952
# 299  0.511020  0.508406  0.306057
#
# [295 rows x 3 columns]

# %%
ndf.reset_index(drop=True)
# Out:
#             A         B         C         D
# 0    0.480224  0.920644  0.908747  0.840264
# 1    0.260703  0.796855  0.599583  0.611426
# 2    0.234726  0.070635  0.724676  0.667663
# 3    0.465776  0.640719  0.194994  0.467065
# 4    0.646736  0.086706  0.478662  0.194198
# ..        ...       ...       ...       ...
# 290  0.593415  0.047831  0.193854  0.773899
# 291  0.652876  0.064104  0.276512  0.482867
# 292  0.073715  0.675179  0.299568  0.362048
# 293  0.608244  0.823857  0.948687  0.724952
# 294  0.174493  0.511020  0.508406  0.306057
#
# [295 rows x 4 columns]

# %%
 ndf
# Out:
#             B         C         D
# 1    0.920644  0.908747  0.840264
# 5    0.796855  0.599583  0.611426
# 7    0.070635  0.724676  0.667663
# 8    0.640719  0.194994  0.467065
# 9    0.086706  0.478662  0.194198
# ..        ...       ...       ...
# 295  0.047831  0.193854  0.773899
# 296  0.064104  0.276512  0.482867
# 297  0.675179  0.299568  0.362048
# 298  0.823857  0.948687  0.724952
# 299  0.511020  0.508406  0.306057
#
# [295 rows x 3 columns]

# %%
ndf.loc[(ndf['B']>0.9)]
# Out:
#             B         C         D
# 1    0.920644  0.908747  0.840264
# 19   0.901892  0.144051  0.240926
# 23   0.985925  0.597239  0.303883
# 27   0.951998  0.068729  0.215231
# 32   0.914251  0.490066  0.590317
# 34   0.975949  0.952023  0.458002
# 38   0.963572  0.734683  0.434950
# 68   0.934381  0.707438  0.110597
# 71   0.940802  0.064280  0.059493
# 77   0.966159  0.526236  0.579441
# 96   0.965443  0.951740  0.217076
# 112  0.910604  0.121757  0.996439
# 119  0.919199  0.038241  0.214083
# 120  0.908699  0.252050  0.677048
# 130  0.965645  0.826117  0.919388
# 153  0.903044  0.925481  0.313828
# 156  0.986595  0.203024  0.320420
# 165  0.981561  0.444621  0.529834
# 174  0.956586  0.666635  0.027953
# 178  0.960526  0.432069  0.160575
# 181  0.931009  0.988222  0.725341
# 186  0.954055  0.202154  0.284089
# 193  0.952617  0.838585  0.619285
# 206  0.955681  0.761049  0.243258
# 219  0.983052  0.455650  0.007695
# 241  0.950900  0.590624  0.341968
# ...

# %%
ndf
# Out:
#             B         C         D
# 1    0.920644  0.908747  0.840264
# 5    0.796855  0.599583  0.611426
# 7    0.070635  0.724676  0.667663
# 8    0.640719  0.194994  0.467065
# 9    0.086706  0.478662  0.194198
# ..        ...       ...       ...
# 295  0.047831  0.193854  0.773899
# 296  0.064104  0.276512  0.482867
# 297  0.675179  0.299568  0.362048
# 298  0.823857  0.948687  0.724952
# 299  0.511020  0.508406  0.306057
#
# [295 rows x 3 columns]

# %%
ndf.drop(('D'),axis=1)
ndf.drop((1),axis=0)
# Out:
#             B         C         D
# 5    0.796855  0.599583  0.611426
# 7    0.070635  0.724676  0.667663
# 8    0.640719  0.194994  0.467065
# 9    0.086706  0.478662  0.194198
# 10   0.413529  0.316443  0.438517
# ..        ...       ...       ...
# 295  0.047831  0.193854  0.773899
# 296  0.064104  0.276512  0.482867
# 297  0.675179  0.299568  0.362048
# 298  0.823857  0.948687  0.724952
# 299  0.511020  0.508406  0.306057
#
# [294 rows x 3 columns]

# %%
ndf
# Out:
#             B         C         D
# 1    0.920644  0.908747  0.840264
# 5    0.796855  0.599583  0.611426
# 7    0.070635  0.724676  0.667663
# 8    0.640719  0.194994  0.467065
# 9    0.086706  0.478662  0.194198
# ..        ...       ...       ...
# 295  0.047831  0.193854  0.773899
# 296  0.064104  0.276512  0.482867
# 297  0.675179  0.299568  0.362048
# 298  0.823857  0.948687  0.724952
# 299  0.511020  0.508406  0.306057
#
# [295 rows x 3 columns]

# %%
ndf.loc[(ndf['B']>0.9)]
# Out:
#             B         C         D
# 1    0.920644  0.908747  0.840264
# 19   0.901892  0.144051  0.240926
# 23   0.985925  0.597239  0.303883
# 27   0.951998  0.068729  0.215231
# 32   0.914251  0.490066  0.590317
# 34   0.975949  0.952023  0.458002
# 38   0.963572  0.734683  0.434950
# 68   0.934381  0.707438  0.110597
# 71   0.940802  0.064280  0.059493
# 77   0.966159  0.526236  0.579441
# 96   0.965443  0.951740  0.217076
# 112  0.910604  0.121757  0.996439
# 119  0.919199  0.038241  0.214083
# 120  0.908699  0.252050  0.677048
# 130  0.965645  0.826117  0.919388
# 153  0.903044  0.925481  0.313828
# 156  0.986595  0.203024  0.320420
# 165  0.981561  0.444621  0.529834
# 174  0.956586  0.666635  0.027953
# 178  0.960526  0.432069  0.160575
# 181  0.931009  0.988222  0.725341
# 186  0.954055  0.202154  0.284089
# 193  0.952617  0.838585  0.619285
# 206  0.955681  0.761049  0.243258
# 219  0.983052  0.455650  0.007695
# 241  0.950900  0.590624  0.341968
# ...

# %%
ndf.shape
# Out:
# (295, 3)
